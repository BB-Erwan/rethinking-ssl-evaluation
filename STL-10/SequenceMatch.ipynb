# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, Subset, Dataset
import sys 
sys.path.append("../")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
num_classes = 10

# Load the STL-10 dataset
train_ds = torchvision.datasets.STL10(root='./data', split='train', download=True, transform=transforms.Resize((32, 32)))
unlabeled_ds_orig = torchvision.datasets.STL10(root='./data', split='unlabeled', download=True, transform=transforms.Resize((32, 32)))
test_ds = torchvision.datasets.STL10(root='./data', split='test', download=True, transform=transforms.Resize((32, 32)))

print(f"Training samples: {len(train_ds)}, Unlabeled samples: {len(unlabeled_ds_orig)}, Test samples: {len(test_ds)}")

mean = torch.tensor([0.4409, 0.4279, 0.3868])
std = torch.tensor([0.2309, 0.2262, 0.2237])
# Out:
# Training samples: 5000, Unlabeled samples: 100000, Test samples: 8000

# %%
class RandomRangAugment(transforms.RandAugment):
    def __init__(self, num_ops=2):
        super().__init__(num_ops=num_ops)

    def __call__(self, img):
        # just randaugment with random magnitude
        self.magnitude = torch.randint(0, self.num_magnitude_bins, (1,)).item()
        img = super().__call__(img)
        return img

# %%
norm_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize(mean, std)
    ])

weak_transform = transforms.Compose([
        transforms.RandomHorizontalFlip(),
        transforms.RandomCrop(32, padding=4),
        transforms.ToTensor(),
        transforms.Normalize(mean, std)
    ])

medium_transform = transforms.Compose([
        transforms.RandomHorizontalFlip(),
        transforms.RandomCrop(32, padding=4),
        RandomRangAugment(num_ops=1),
        transforms.ToTensor(),
        transforms.Normalize(mean, std),
        transforms.RandomErasing(),
    ])

strong_transform=transforms.Compose([
        RandomRangAugment(num_ops=3),
        transforms.ToTensor(),
        transforms.Normalize(mean, std),
        transforms.RandomErasing()
    ])

# %%
# Test transformation on a sample image
import matplotlib.pyplot as plt
def imshow(img, title=None):
    img = img * std[:, None, None] + mean[:, None, None]  # unnormalize
    img = img.permute(1, 2, 0).numpy()  # CxHxW to HxWxC
    plt.imshow(img)
    if title:
        plt.title(title)
    plt.axis('off')
sample_img, sample_label = train_ds[0]
plt.figure(figsize=(12, 4))
plt.subplot(1, 4, 1)
imshow(norm_transform(sample_img), title="Original")
plt.subplot(1, 4, 2)
imshow(weak_transform(sample_img), title="Weak")
plt.subplot(1, 4, 3)
imshow(medium_transform(sample_img), title="Medium")
plt.subplot(1, 4, 4)
imshow(strong_transform(sample_img), title="Strong")
plt.show()

# %%
class UnlabeledDataset(Dataset):
    def __init__(self, dataset, weak_transform, medium_transform, strong_transform):
        self.dataset = dataset
        self.weak_transform = weak_transform
        self.medium_transform = medium_transform
        self.strong_transform = strong_transform

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        x, _ = self.dataset[idx]
        x_w = self.weak_transform(x)
        x_m = self.medium_transform(x)
        x_s = self.strong_transform(x)
        return x_w, x_m, x_s, idx

# %%
from datasets import TransformedDataset
from wideresnet2 import WideResNet 
from utils import evaluate_f1_and_accuracy
import os
import json
import time

num_runs = 3

test_ds = TransformedDataset(test_ds, norm_transform)

for run in range(num_runs):
    print(f"Run {run+1}/{num_runs}")

    # Init random seeds for reproducibility
    torch.manual_seed(run)
    num_labeled = 1000
    perm_indices = torch.randperm(len(train_ds))
    labeled_indices = perm_indices[:num_labeled]
    unlabeled_indices = perm_indices[num_labeled:]

    # Create datasets and dataloaders
    labeled_ds = TransformedDataset(Subset(train_ds, labeled_indices), weak_transform)
    # conctanenate the unlabeled dataset with the unlabeled split of the original dataset to ensure we have the correct number of unlabeled samples
    unlabeled_ds_concat = torch.utils.data.ConcatDataset([
        Subset(train_ds, unlabeled_indices),
        unlabeled_ds_orig
    ])
    unlabeled_ds = UnlabeledDataset(unlabeled_ds_concat, weak_transform, medium_transform, strong_transform)


    # Create dataloaders
    batch_size = 64
    mu = 7
    labeled_loader = DataLoader(labeled_ds, batch_size=batch_size, shuffle=True)
    unlabeled_loader = DataLoader(unlabeled_ds, batch_size=batch_size*mu, shuffle=True)
    test_loader = DataLoader(test_ds, batch_size=batch_size, shuffle=False)

    # Create iterators for the dataloaders
    labeled_iter = iter(labeled_loader)
    unlabeled_iter = iter(unlabeled_loader)

    # Define the model
    model = WideResNet(depth=28, widen_factor=2, num_classes=num_classes).to(device)
    max_steps = 1_490  # Equivalent to 20 epochs on the full dataset with batch size 64
    optimizer = torch.optim.SGD(model.parameters(), lr=0.03, momentum=0.9, weight_decay=5e-4, nesterov=True)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=max_steps)

    # Settings
    method_name = "SequenceMatch"
    name_of_experiment = f"stl10_{num_labeled}_labels_run_{run+1}"

    if os.path.exists(f"results/{name_of_experiment}/{method_name}.json"):
        print(f"Results for {name_of_experiment} already exist. Skipping saving to avoid overwriting.")
        continue # this will skip the rest of the training loop and move to the next run

    # Metrics to track
    metrics = {
    "test_f1": [0.0],  # Start with 0% F1 before training
    "test_acc": [0.0],  # Start with 0% accuracy before training
    "budget": [0]
    }

    # Hyperparameters
    tau = 0.95
    T = 0.5
    budget_per_iteration = 1 + 3 * mu  # 1 batch of labeled + 3 batches of unlabeled (weak + medium + strong)
    test_budget_period = 700  # Evaluate on test set every 700 batches seen

    # Training loop
    current_budget = 0
    start_time = time.time()
    for step in range(max_steps):
        running_loss = 0.0
        running_loss_sup = 0.0
        running_loss_unsup = 0.0
        model.train()
        try:
            x_l, y_l = next(labeled_iter)
        except StopIteration:
            labeled_iter = iter(labeled_loader)
            x_l, y_l = next(labeled_iter)

        try:
            x_u_w, x_u_m, x_u_s, _ = next(unlabeled_iter)
        except StopIteration:
            unlabeled_iter = iter(unlabeled_loader)
            x_u_w, x_u_m, x_u_s, _ = next(unlabeled_iter)

        x_l, y_l = x_l.to(device), y_l.to(device)
        x_u_w, x_u_m, x_u_s = x_u_w.to(device), x_u_m.to(device), x_u_s.to(device)

        # supervised
        logits_l = model(x_l)
        loss_sup = F.cross_entropy(logits_l, y_l)

        # compute prediction on weakly augmented samples for pseudo-labeling and confidence-based masking
        logits_m = model(x_u_m)
        logits_s = model(x_u_s)
        with torch.no_grad():
            logits_w = model(x_u_w)
            probs_w = F.softmax(logits_w, dim=1)
            sharpened_probs_w = F.softmax(logits_w / T, dim=1)
            max_prob_w, pseudo_w = torch.max(probs_w, dim=1)
            mask_w = max_prob_w.ge(tau).float()

            probs_m = F.softmax(logits_m, dim=1)
            sharpened_probs_m = F.softmax(logits_m / T, dim=1)
            max_prob_m, pseudo_m = torch.max(probs_m, dim=1)
            mask_m = max_prob_m.ge(tau).float()

        loss_unsup_conf = (mask_w * F.cross_entropy(logits_s, pseudo_w, reduction='none')).mean()

        loss_consistency = loss_unsup_conf

        loss_w_m = (mask_w * F.kl_div(F.log_softmax(logits_m, dim=1), sharpened_probs_w, reduction='none').sum(dim=1)).mean()
        loss_m_s = (mask_m * F.kl_div(F.log_softmax(logits_s, dim=1), sharpened_probs_m, reduction='none').sum(dim=1)).mean()
        loss_w_s = (mask_w * F.kl_div(F.log_softmax(logits_s, dim=1), sharpened_probs_w, reduction='none').sum(dim=1)).mean()

        loss_unsup = loss_w_m + loss_m_s + loss_w_s  + loss_consistency 

        loss = loss_sup + loss_unsup
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        scheduler.step()

        running_loss += loss.item()
        running_loss_sup += loss_sup.item()
        running_loss_unsup += loss_unsup.item()

        current_budget += budget_per_iteration

        if current_budget % test_budget_period < budget_per_iteration:
            f1, acc = evaluate_f1_and_accuracy(model, test_loader, device)
            metrics["test_f1"].append(f1)
            metrics["test_acc"].append(acc)
            metrics["budget"].append(current_budget)
            elapsed_time = time.time() - start_time
            print(f"Step {step+1}/{max_steps}, Budget: {current_budget}, Loss: {running_loss:.4f}, Sup Loss: {running_loss_sup:.4f}, Unsup Loss: {running_loss_unsup:.4f}, Test F1: {f1:.4f}, Test Acc: {acc:.4f}, Elapsed Time: {elapsed_time:.2f}s", flush=True)

            os.makedirs("results", exist_ok=True)
            os.makedirs(f"results/{name_of_experiment}", exist_ok=True)
            with open(f"results/{name_of_experiment}/{method_name}.json", "w") as f:
                json.dump(metrics, f, indent=4)

            # Early stopping if divergence is detected (accuracy does not go above 11% for 5 consecutive evaluations)
            early_stopping = (num_labeled == 40) and len(metrics["test_acc"]) > 5 and all(acc < 0.11 for acc in metrics["test_acc"][-6:-1])
            if early_stopping:
                print(f"Early stopping at step {step+1} due to accuracy stagnating.")
                
                # Fill the remaining metrics with the last known values until max_steps
                for remaining_step in range(step+1, max_steps):
                    current_budget += budget_per_iteration
                    if current_budget % test_budget_period < budget_per_iteration:
                        metrics["test_f1"].append(metrics["test_f1"][-1])  # Append last known F1
                        metrics["test_acc"].append(metrics["test_acc"][-1])  # Append last known accuracy
                        metrics["budget"].append(current_budget)
                # Save the final metrics after early stopping
                with open(f"results/{name_of_experiment}/{method_name}.json", "w") as f:
                    json.dump(metrics, f, indent=4)
                break 

        elif step+1 == max_steps: # Final evaluation at the end of training
            f1, acc = evaluate_f1_and_accuracy(model, test_loader, device)
            metrics["test_f1"].append(f1)
            metrics["test_acc"].append(acc)
            metrics["budget"].append(current_budget)
            elapsed_time = time.time() - start_time
            print(f"Step {step+1}/{max_steps}, Budget: {current_budget}, Loss: {running_loss:.4f}, Sup Loss: {running_loss_sup:.4f}, Unsup Loss: {running_loss_unsup:.4f}, Test F1: {f1:.4f}, Test Acc: {acc:.4f}, Elapsed Time: {elapsed_time:.2f}s", flush=True)

            os.makedirs("results", exist_ok=True)
            os.makedirs(f"results/{name_of_experiment}", exist_ok=True)
            with open(f"results/{name_of_experiment}/{method_name}.json", "w") as f:
                json.dump(metrics, f, indent=4) 

        else:
            print(f"Step {step+1}/{max_steps}, Budget: {current_budget}, Loss: {running_loss:.4f}, Sup Loss: {running_loss_sup:.4f}, Unsup Loss: {running_loss_unsup:.4f}", end="\r", flush=True)
# Out:
# Run 1/3
# Step 32/1490, Budget: 704, Loss: 2.0875, Sup Loss: 2.0875, Unsup Loss: 0.0000, Test F1: 0.1559, Test Acc: 0.2409, Elapsed Time: 43.72s
# Step 64/1490, Budget: 1408, Loss: 1.6792, Sup Loss: 1.6713, Unsup Loss: 0.0079, Test F1: 0.2176, Test Acc: 0.2869, Elapsed Time: 86.53s
# Step 96/1490, Budget: 2112, Loss: 1.3535, Sup Loss: 1.3520, Unsup Loss: 0.0015, Test F1: 0.2208, Test Acc: 0.2755, Elapsed Time: 128.85s
# Step 128/1490, Budget: 2816, Loss: 1.7711, Sup Loss: 1.7365, Unsup Loss: 0.0346, Test F1: 0.2929, Test Acc: 0.3340, Elapsed Time: 170.58s
# Step 160/1490, Budget: 3520, Loss: 1.6204, Sup Loss: 1.5299, Unsup Loss: 0.0905, Test F1: 0.2954, Test Acc: 0.3365, Elapsed Time: 212.33s
# Step 191/1490, Budget: 4202, Loss: 1.2926, Sup Loss: 1.2178, Unsup Loss: 0.0749, Test F1: 0.3456, Test Acc: 0.3651, Elapsed Time: 254.35s
# Step 223/1490, Budget: 4906, Loss: 1.6234, Sup Loss: 1.5186, Unsup Loss: 0.1049, Test F1: 0.3343, Test Acc: 0.3558, Elapsed Time: 296.83s
# Step 255/1490, Budget: 5610, Loss: 1.2934, Sup Loss: 1.2220, Unsup Loss: 0.0713, Test F1: 0.3383, Test Acc: 0.3814, Elapsed Time: 338.06s
# Step 287/1490, Budget: 6314, Loss: 1.4505, Sup Loss: 1.3204, Unsup Loss: 0.1300, Test F1: 0.3712, Test Acc: 0.4105, Elapsed Time: 380.53s
# Step 319/1490, Budget: 7018, Loss: 1.1942, Sup Loss: 1.0567, Unsup Loss: 0.1376, Test F1: 0.4136, Test Acc: 0.4243, Elapsed Time: 422.89s
# Step 350/1490, Budget: 7700, Loss: 1.3762, Sup Loss: 1.2086, Unsup Loss: 0.1675, Test F1: 0.3605, Test Acc: 0.3797, Elapsed Time: 464.17s
# Step 382/1490, Budget: 8404, Loss: 1.0958, Sup Loss: 0.8679, Unsup Loss: 0.2280, Test F1: 0.4149, Test Acc: 0.4278, Elapsed Time: 506.30s
# Step 414/1490, Budget: 9108, Loss: 1.0801, Sup Loss: 0.9304, Unsup Loss: 0.1497, Test F1: 0.3442, Test Acc: 0.3967, Elapsed Time: 547.19s
# Step 446/1490, Budget: 9812, Loss: 1.1000, Sup Loss: 0.9375, Unsup Loss: 0.1625, Test F1: 0.4220, Test Acc: 0.4524, Elapsed Time: 587.95s
# Step 478/1490, Budget: 10516, Loss: 1.1394, Sup Loss: 0.8022, Unsup Loss: 0.3371, Test F1: 0.4145, Test Acc: 0.4415, Elapsed Time: 627.66s
# Step 510/1490, Budget: 11220, Loss: 1.1773, Sup Loss: 0.8372, Unsup Loss: 0.3401, Test F1: 0.3856, Test Acc: 0.4178, Elapsed Time: 668.50s
# Step 541/1490, Budget: 11902, Loss: 0.8266, Sup Loss: 0.5322, Unsup Loss: 0.2945, Test F1: 0.4452, Test Acc: 0.4560, Elapsed Time: 708.10s
# Step 573/1490, Budget: 12606, Loss: 0.9931, Sup Loss: 0.5816, Unsup Loss: 0.4114, Test F1: 0.4492, Test Acc: 0.4585, Elapsed Time: 749.00s
# Step 605/1490, Budget: 13310, Loss: 1.0330, Sup Loss: 0.6713, Unsup Loss: 0.3617, Test F1: 0.4564, Test Acc: 0.4711, Elapsed Time: 789.92s
# Step 637/1490, Budget: 14014, Loss: 0.9547, Sup Loss: 0.3641, Unsup Loss: 0.5906, Test F1: 0.4807, Test Acc: 0.4811, Elapsed Time: 830.72s
# Step 669/1490, Budget: 14718, Loss: 0.8939, Sup Loss: 0.4071, Unsup Loss: 0.4868, Test F1: 0.4610, Test Acc: 0.4785, Elapsed Time: 871.55s
# Step 700/1490, Budget: 15400, Loss: 0.8564, Sup Loss: 0.3680, Unsup Loss: 0.4884, Test F1: 0.4863, Test Acc: 0.4996, Elapsed Time: 910.14s
# Step 732/1490, Budget: 16104, Loss: 0.8061, Sup Loss: 0.2798, Unsup Loss: 0.5263, Test F1: 0.4882, Test Acc: 0.5011, Elapsed Time: 950.93s
# Step 764/1490, Budget: 16808, Loss: 0.8601, Sup Loss: 0.3033, Unsup Loss: 0.5568, Test F1: 0.4904, Test Acc: 0.4996, Elapsed Time: 991.75s
# Step 796/1490, Budget: 17512, Loss: 0.8312, Sup Loss: 0.3716, Unsup Loss: 0.4595, Test F1: 0.4857, Test Acc: 0.4956, Elapsed Time: 1032.64s
# Step 828/1490, Budget: 18216, Loss: 0.7411, Sup Loss: 0.2208, Unsup Loss: 0.5203, Test F1: 0.4887, Test Acc: 0.4981, Elapsed Time: 1073.47s
# Step 860/1490, Budget: 18920, Loss: 0.6497, Sup Loss: 0.1972, Unsup Loss: 0.4524, Test F1: 0.4889, Test Acc: 0.5068, Elapsed Time: 1114.29s
# Step 891/1490, Budget: 19602, Loss: 1.0061, Sup Loss: 0.2761, Unsup Loss: 0.7299, Test F1: 0.5151, Test Acc: 0.5246, Elapsed Time: 1153.86s
# Step 923/1490, Budget: 20306, Loss: 0.9278, Sup Loss: 0.2865, Unsup Loss: 0.6412, Test F1: 0.4946, Test Acc: 0.5092, Elapsed Time: 1194.69s
# Step 955/1490, Budget: 21010, Loss: 0.7895, Sup Loss: 0.0556, Unsup Loss: 0.7339, Test F1: 0.5073, Test Acc: 0.5188, Elapsed Time: 1234.50s
# Step 987/1490, Budget: 21714, Loss: 0.8027, Sup Loss: 0.1535, Unsup Loss: 0.6493, Test F1: 0.5219, Test Acc: 0.5260, Elapsed Time: 1275.30s
# Step 1019/1490, Budget: 22418, Loss: 0.7251, Sup Loss: 0.1390, Unsup Loss: 0.5861, Test F1: 0.5149, Test Acc: 0.5230, Elapsed Time: 1316.15s
# Step 1050/1490, Budget: 23100, Loss: 0.8488, Sup Loss: 0.1485, Unsup Loss: 0.7003, Test F1: 0.5050, Test Acc: 0.5186, Elapsed Time: 1355.69s
# Step 1082/1490, Budget: 23804, Loss: 0.7533, Sup Loss: 0.0769, Unsup Loss: 0.6764, Test F1: 0.5184, Test Acc: 0.5261, Elapsed Time: 1396.47s
# Step 1114/1490, Budget: 24508, Loss: 0.7029, Sup Loss: 0.1375, Unsup Loss: 0.5654, Test F1: 0.5157, Test Acc: 0.5242, Elapsed Time: 1437.28s
# Step 1146/1490, Budget: 25212, Loss: 0.7977, Sup Loss: 0.1096, Unsup Loss: 0.6881, Test F1: 0.5272, Test Acc: 0.5339, Elapsed Time: 1478.10s
# Step 1178/1490, Budget: 25916, Loss: 0.8115, Sup Loss: 0.1171, Unsup Loss: 0.6945, Test F1: 0.5271, Test Acc: 0.5300, Elapsed Time: 1517.79s
# Step 1210/1490, Budget: 26620, Loss: 0.7695, Sup Loss: 0.1074, Unsup Loss: 0.6621, Test F1: 0.5256, Test Acc: 0.5311, Elapsed Time: 1558.59s
# Step 1241/1490, Budget: 27302, Loss: 0.7506, Sup Loss: 0.0575, Unsup Loss: 0.6931, Test F1: 0.5286, Test Acc: 0.5361, Elapsed Time: 1598.10s
# Step 1273/1490, Budget: 28006, Loss: 0.7522, Sup Loss: 0.0846, Unsup Loss: 0.6676, Test F1: 0.5248, Test Acc: 0.5336, Elapsed Time: 1638.91s
# Step 1305/1490, Budget: 28710, Loss: 0.7740, Sup Loss: 0.0489, Unsup Loss: 0.7250, Test F1: 0.5321, Test Acc: 0.5373, Elapsed Time: 1679.67s
# Step 1337/1490, Budget: 29414, Loss: 0.5892, Sup Loss: 0.0424, Unsup Loss: 0.5468, Test F1: 0.5259, Test Acc: 0.5336, Elapsed Time: 1720.48s
# Step 1369/1490, Budget: 30118, Loss: 0.7461, Sup Loss: 0.0953, Unsup Loss: 0.6508, Test F1: 0.5301, Test Acc: 0.5359, Elapsed Time: 1761.41s
# Step 1400/1490, Budget: 30800, Loss: 0.6773, Sup Loss: 0.0656, Unsup Loss: 0.6117, Test F1: 0.5267, Test Acc: 0.5343, Elapsed Time: 1799.87s
# Step 1432/1490, Budget: 31504, Loss: 0.6477, Sup Loss: 0.0879, Unsup Loss: 0.5598, Test F1: 0.5252, Test Acc: 0.5334, Elapsed Time: 1840.67s
# Step 1464/1490, Budget: 32208, Loss: 0.7691, Sup Loss: 0.0584, Unsup Loss: 0.7107, Test F1: 0.5266, Test Acc: 0.5334, Elapsed Time: 1881.45s
# Step 1490/1490, Budget: 32780, Loss: 0.8642, Sup Loss: 0.0825, Unsup Loss: 0.7817, Test F1: 0.5262, Test Acc: 0.5340, Elapsed Time: 1914.86s
# Run 2/3
# Step 32/1490, Budget: 704, Loss: 1.9441, Sup Loss: 1.9441, Unsup Loss: 0.0000, Test F1: 0.1535, Test Acc: 0.2265, Elapsed Time: 40.87s
# Step 64/1490, Budget: 1408, Loss: 1.7149, Sup Loss: 1.7149, Unsup Loss: 0.0000, Test F1: 0.2407, Test Acc: 0.2831, Elapsed Time: 81.66s
# Step 96/1490, Budget: 2112, Loss: 1.6278, Sup Loss: 1.6247, Unsup Loss: 0.0031, Test F1: 0.2351, Test Acc: 0.2700, Elapsed Time: 122.46s
# Step 128/1490, Budget: 2816, Loss: 1.6542, Sup Loss: 1.6112, Unsup Loss: 0.0430, Test F1: 0.2952, Test Acc: 0.3184, Elapsed Time: 163.26s
# Step 160/1490, Budget: 3520, Loss: 1.6794, Sup Loss: 1.4923, Unsup Loss: 0.1871, Test F1: 0.3097, Test Acc: 0.3319, Elapsed Time: 204.09s
# Step 191/1490, Budget: 4202, Loss: 1.5886, Sup Loss: 1.4960, Unsup Loss: 0.0926, Test F1: 0.3336, Test Acc: 0.3514, Elapsed Time: 243.71s
# Step 223/1490, Budget: 4906, Loss: 1.3477, Sup Loss: 1.1990, Unsup Loss: 0.1487, Test F1: 0.3725, Test Acc: 0.3886, Elapsed Time: 284.51s
# Step 255/1490, Budget: 5610, Loss: 1.6143, Sup Loss: 1.4017, Unsup Loss: 0.2126, Test F1: 0.3785, Test Acc: 0.3964, Elapsed Time: 324.31s
# Step 287/1490, Budget: 6314, Loss: 1.2071, Sup Loss: 1.1558, Unsup Loss: 0.0513, Test F1: 0.4119, Test Acc: 0.4231, Elapsed Time: 365.25s
# Step 319/1490, Budget: 7018, Loss: 1.4574, Sup Loss: 1.2516, Unsup Loss: 0.2058, Test F1: 0.4318, Test Acc: 0.4381, Elapsed Time: 406.04s
# Step 350/1490, Budget: 7700, Loss: 1.2662, Sup Loss: 1.0952, Unsup Loss: 0.1710, Test F1: 0.4343, Test Acc: 0.4469, Elapsed Time: 445.61s
# Step 382/1490, Budget: 8404, Loss: 1.3749, Sup Loss: 1.1949, Unsup Loss: 0.1801, Test F1: 0.4005, Test Acc: 0.4124, Elapsed Time: 486.45s
# Step 414/1490, Budget: 9108, Loss: 1.1724, Sup Loss: 0.9430, Unsup Loss: 0.2294, Test F1: 0.4526, Test Acc: 0.4556, Elapsed Time: 527.24s
# Step 446/1490, Budget: 9812, Loss: 1.0723, Sup Loss: 0.8557, Unsup Loss: 0.2166, Test F1: 0.4211, Test Acc: 0.4382, Elapsed Time: 568.07s
# Step 478/1490, Budget: 10516, Loss: 0.9173, Sup Loss: 0.7124, Unsup Loss: 0.2049, Test F1: 0.4467, Test Acc: 0.4636, Elapsed Time: 607.86s
# Step 510/1490, Budget: 11220, Loss: 1.3541, Sup Loss: 0.9605, Unsup Loss: 0.3935, Test F1: 0.4175, Test Acc: 0.4414, Elapsed Time: 648.63s
# Step 541/1490, Budget: 11902, Loss: 1.4159, Sup Loss: 0.9551, Unsup Loss: 0.4608, Test F1: 0.4887, Test Acc: 0.4955, Elapsed Time: 688.29s
# Step 573/1490, Budget: 12606, Loss: 1.0749, Sup Loss: 0.6231, Unsup Loss: 0.4518, Test F1: 0.4701, Test Acc: 0.4801, Elapsed Time: 729.07s
# Step 605/1490, Budget: 13310, Loss: 1.1271, Sup Loss: 0.7305, Unsup Loss: 0.3965, Test F1: 0.4916, Test Acc: 0.4996, Elapsed Time: 769.85s
# Step 637/1490, Budget: 14014, Loss: 0.9807, Sup Loss: 0.5048, Unsup Loss: 0.4759, Test F1: 0.4881, Test Acc: 0.4958, Elapsed Time: 810.67s
# Step 669/1490, Budget: 14718, Loss: 0.8273, Sup Loss: 0.4001, Unsup Loss: 0.4271, Test F1: 0.5035, Test Acc: 0.5115, Elapsed Time: 851.46s
# Step 700/1490, Budget: 15400, Loss: 1.0974, Sup Loss: 0.5062, Unsup Loss: 0.5912, Test F1: 0.4846, Test Acc: 0.4976, Elapsed Time: 889.96s
# Step 732/1490, Budget: 16104, Loss: 0.8590, Sup Loss: 0.4055, Unsup Loss: 0.4535, Test F1: 0.5190, Test Acc: 0.5238, Elapsed Time: 930.76s
# Step 764/1490, Budget: 16808, Loss: 1.0126, Sup Loss: 0.4040, Unsup Loss: 0.6087, Test F1: 0.5202, Test Acc: 0.5226, Elapsed Time: 971.55s
# Step 796/1490, Budget: 17512, Loss: 0.7990, Sup Loss: 0.2409, Unsup Loss: 0.5581, Test F1: 0.4991, Test Acc: 0.5029, Elapsed Time: 1012.36s
# Step 828/1490, Budget: 18216, Loss: 0.7145, Sup Loss: 0.2016, Unsup Loss: 0.5129, Test F1: 0.5279, Test Acc: 0.5281, Elapsed Time: 1053.21s
# Step 860/1490, Budget: 18920, Loss: 0.8022, Sup Loss: 0.2427, Unsup Loss: 0.5594, Test F1: 0.5279, Test Acc: 0.5343, Elapsed Time: 1094.01s
# Step 891/1490, Budget: 19602, Loss: 0.8690, Sup Loss: 0.2396, Unsup Loss: 0.6293, Test F1: 0.5300, Test Acc: 0.5337, Elapsed Time: 1133.61s
# Step 923/1490, Budget: 20306, Loss: 0.9819, Sup Loss: 0.1808, Unsup Loss: 0.8011, Test F1: 0.5405, Test Acc: 0.5420, Elapsed Time: 1174.37s
# Step 955/1490, Budget: 21010, Loss: 0.8143, Sup Loss: 0.1361, Unsup Loss: 0.6782, Test F1: 0.5459, Test Acc: 0.5485, Elapsed Time: 1214.06s
# Step 987/1490, Budget: 21714, Loss: 0.7740, Sup Loss: 0.1460, Unsup Loss: 0.6280, Test F1: 0.5506, Test Acc: 0.5560, Elapsed Time: 1254.96s
# Step 1019/1490, Budget: 22418, Loss: 0.8105, Sup Loss: 0.1362, Unsup Loss: 0.6743, Test F1: 0.5447, Test Acc: 0.5531, Elapsed Time: 1295.76s
# Step 1050/1490, Budget: 23100, Loss: 0.9668, Sup Loss: 0.1034, Unsup Loss: 0.8634, Test F1: 0.5467, Test Acc: 0.5487, Elapsed Time: 1335.31s
# Step 1082/1490, Budget: 23804, Loss: 0.6669, Sup Loss: 0.1015, Unsup Loss: 0.5653, Test F1: 0.5562, Test Acc: 0.5573, Elapsed Time: 1376.06s
# Step 1114/1490, Budget: 24508, Loss: 0.8415, Sup Loss: 0.1439, Unsup Loss: 0.6976, Test F1: 0.5541, Test Acc: 0.5529, Elapsed Time: 1416.86s
# Step 1146/1490, Budget: 25212, Loss: 0.8425, Sup Loss: 0.2145, Unsup Loss: 0.6280, Test F1: 0.5629, Test Acc: 0.5635, Elapsed Time: 1457.63s
# Step 1178/1490, Budget: 25916, Loss: 0.7562, Sup Loss: 0.0627, Unsup Loss: 0.6935, Test F1: 0.5579, Test Acc: 0.5581, Elapsed Time: 1497.31s
# Step 1210/1490, Budget: 26620, Loss: 0.7793, Sup Loss: 0.1548, Unsup Loss: 0.6245, Test F1: 0.5611, Test Acc: 0.5649, Elapsed Time: 1538.11s
# Step 1241/1490, Budget: 27302, Loss: 0.8339, Sup Loss: 0.1107, Unsup Loss: 0.7232, Test F1: 0.5638, Test Acc: 0.5656, Elapsed Time: 1577.67s
# Step 1273/1490, Budget: 28006, Loss: 0.9183, Sup Loss: 0.0845, Unsup Loss: 0.8338, Test F1: 0.5667, Test Acc: 0.5681, Elapsed Time: 1618.50s
# Step 1305/1490, Budget: 28710, Loss: 0.7856, Sup Loss: 0.0530, Unsup Loss: 0.7326, Test F1: 0.5683, Test Acc: 0.5696, Elapsed Time: 1659.40s
# Step 1337/1490, Budget: 29414, Loss: 0.9490, Sup Loss: 0.0854, Unsup Loss: 0.8636, Test F1: 0.5661, Test Acc: 0.5681, Elapsed Time: 1700.22s
# Step 1369/1490, Budget: 30118, Loss: 0.6902, Sup Loss: 0.0486, Unsup Loss: 0.6416, Test F1: 0.5673, Test Acc: 0.5686, Elapsed Time: 1741.03s
# Step 1400/1490, Budget: 30800, Loss: 0.7146, Sup Loss: 0.0679, Unsup Loss: 0.6467, Test F1: 0.5667, Test Acc: 0.5689, Elapsed Time: 1779.48s
# Step 1432/1490, Budget: 31504, Loss: 0.8373, Sup Loss: 0.0944, Unsup Loss: 0.7428, Test F1: 0.5685, Test Acc: 0.5700, Elapsed Time: 1820.32s
# Step 1464/1490, Budget: 32208, Loss: 0.7101, Sup Loss: 0.0663, Unsup Loss: 0.6438, Test F1: 0.5712, Test Acc: 0.5723, Elapsed Time: 1861.14s
# Step 1490/1490, Budget: 32780, Loss: 0.7750, Sup Loss: 0.0599, Unsup Loss: 0.7152, Test F1: 0.5701, Test Acc: 0.5715, Elapsed Time: 1894.55s
# Run 3/3
# Step 32/1490, Budget: 704, Loss: 1.9363, Sup Loss: 1.9363, Unsup Loss: 0.0000, Test F1: 0.1779, Test Acc: 0.2417, Elapsed Time: 40.79s
# Step 64/1490, Budget: 1408, Loss: 1.6648, Sup Loss: 1.6648, Unsup Loss: 0.0000, Test F1: 0.2370, Test Acc: 0.2974, Elapsed Time: 81.65s
# Step 96/1490, Budget: 2112, Loss: 1.6708, Sup Loss: 1.5035, Unsup Loss: 0.1673, Test F1: 0.2500, Test Acc: 0.3045, Elapsed Time: 122.61s
# Step 128/1490, Budget: 2816, Loss: 1.4112, Sup Loss: 1.3939, Unsup Loss: 0.0174, Test F1: 0.2891, Test Acc: 0.3151, Elapsed Time: 163.40s
# Step 160/1490, Budget: 3520, Loss: 1.3858, Sup Loss: 1.3748, Unsup Loss: 0.0110, Test F1: 0.3404, Test Acc: 0.3648, Elapsed Time: 204.20s
# Step 191/1490, Budget: 4202, Loss: 1.5328, Sup Loss: 1.4894, Unsup Loss: 0.0434, Test F1: 0.3735, Test Acc: 0.3949, Elapsed Time: 243.84s
# Step 223/1490, Budget: 4906, Loss: 1.6089, Sup Loss: 1.5586, Unsup Loss: 0.0504, Test F1: 0.3434, Test Acc: 0.3641, Elapsed Time: 284.66s
# Step 255/1490, Budget: 5610, Loss: 1.4900, Sup Loss: 1.3870, Unsup Loss: 0.1030, Test F1: 0.3385, Test Acc: 0.3696, Elapsed Time: 324.41s
# Step 287/1490, Budget: 6314, Loss: 1.5483, Sup Loss: 1.4212, Unsup Loss: 0.1271, Test F1: 0.3991, Test Acc: 0.4143, Elapsed Time: 365.22s
# Step 319/1490, Budget: 7018, Loss: 1.4297, Sup Loss: 1.2884, Unsup Loss: 0.1413, Test F1: 0.4371, Test Acc: 0.4442, Elapsed Time: 406.03s
# Step 350/1490, Budget: 7700, Loss: 1.3366, Sup Loss: 1.2004, Unsup Loss: 0.1362, Test F1: 0.4453, Test Acc: 0.4667, Elapsed Time: 445.60s
# Step 382/1490, Budget: 8404, Loss: 1.0386, Sup Loss: 0.9505, Unsup Loss: 0.0881, Test F1: 0.4401, Test Acc: 0.4577, Elapsed Time: 486.41s
# Step 414/1490, Budget: 9108, Loss: 1.0415, Sup Loss: 0.9414, Unsup Loss: 0.1001, Test F1: 0.4198, Test Acc: 0.4348, Elapsed Time: 527.23s
# Step 446/1490, Budget: 9812, Loss: 1.2732, Sup Loss: 0.9744, Unsup Loss: 0.2988, Test F1: 0.4511, Test Acc: 0.4665, Elapsed Time: 568.02s
# Step 478/1490, Budget: 10516, Loss: 1.5076, Sup Loss: 1.0989, Unsup Loss: 0.4086, Test F1: 0.4503, Test Acc: 0.4641, Elapsed Time: 607.74s
# Step 510/1490, Budget: 11220, Loss: 1.0412, Sup Loss: 0.8196, Unsup Loss: 0.2216, Test F1: 0.4618, Test Acc: 0.4704, Elapsed Time: 648.58s
# Step 541/1490, Budget: 11902, Loss: 1.1580, Sup Loss: 0.7926, Unsup Loss: 0.3654, Test F1: 0.4565, Test Acc: 0.4734, Elapsed Time: 688.23s
# Step 573/1490, Budget: 12606, Loss: 0.8694, Sup Loss: 0.5653, Unsup Loss: 0.3041, Test F1: 0.4720, Test Acc: 0.4728, Elapsed Time: 729.10s
# Step 605/1490, Budget: 13310, Loss: 1.0102, Sup Loss: 0.6656, Unsup Loss: 0.3447, Test F1: 0.4621, Test Acc: 0.4769, Elapsed Time: 769.90s
# Step 637/1490, Budget: 14014, Loss: 0.9742, Sup Loss: 0.5232, Unsup Loss: 0.4510, Test F1: 0.4936, Test Acc: 0.5024, Elapsed Time: 810.70s
# Step 669/1490, Budget: 14718, Loss: 1.0647, Sup Loss: 0.5664, Unsup Loss: 0.4983, Test F1: 0.4994, Test Acc: 0.5111, Elapsed Time: 851.53s
# Step 700/1490, Budget: 15400, Loss: 0.9303, Sup Loss: 0.4411, Unsup Loss: 0.4892, Test F1: 0.4962, Test Acc: 0.5045, Elapsed Time: 890.02s
# Step 732/1490, Budget: 16104, Loss: 0.9253, Sup Loss: 0.3222, Unsup Loss: 0.6031, Test F1: 0.4950, Test Acc: 0.5006, Elapsed Time: 930.84s
# Step 764/1490, Budget: 16808, Loss: 0.9696, Sup Loss: 0.3994, Unsup Loss: 0.5702, Test F1: 0.5250, Test Acc: 0.5218, Elapsed Time: 971.78s
# Step 796/1490, Budget: 17512, Loss: 1.0763, Sup Loss: 0.5018, Unsup Loss: 0.5745, Test F1: 0.4833, Test Acc: 0.4995, Elapsed Time: 1012.61s
# Step 828/1490, Budget: 18216, Loss: 0.8128, Sup Loss: 0.3476, Unsup Loss: 0.4652, Test F1: 0.5093, Test Acc: 0.5164, Elapsed Time: 1053.46s
# Step 860/1490, Budget: 18920, Loss: 0.9905, Sup Loss: 0.3076, Unsup Loss: 0.6829, Test F1: 0.5057, Test Acc: 0.5075, Elapsed Time: 1094.31s
# Step 891/1490, Budget: 19602, Loss: 0.8731, Sup Loss: 0.1557, Unsup Loss: 0.7174, Test F1: 0.4984, Test Acc: 0.5121, Elapsed Time: 1133.89s
# Step 923/1490, Budget: 20306, Loss: 0.9386, Sup Loss: 0.1622, Unsup Loss: 0.7764, Test F1: 0.5212, Test Acc: 0.5272, Elapsed Time: 1174.69s
# Step 955/1490, Budget: 21010, Loss: 0.8140, Sup Loss: 0.1603, Unsup Loss: 0.6537, Test F1: 0.5286, Test Acc: 0.5300, Elapsed Time: 1214.37s
# Step 987/1490, Budget: 21714, Loss: 0.9567, Sup Loss: 0.1653, Unsup Loss: 0.7914, Test F1: 0.5287, Test Acc: 0.5350, Elapsed Time: 1255.20s
# Step 1019/1490, Budget: 22418, Loss: 0.8106, Sup Loss: 0.0801, Unsup Loss: 0.7305, Test F1: 0.5298, Test Acc: 0.5371, Elapsed Time: 1296.07s
# Step 1050/1490, Budget: 23100, Loss: 0.7589, Sup Loss: 0.1404, Unsup Loss: 0.6184, Test F1: 0.5362, Test Acc: 0.5391, Elapsed Time: 1335.67s
# Step 1082/1490, Budget: 23804, Loss: 0.9346, Sup Loss: 0.1077, Unsup Loss: 0.8268, Test F1: 0.5252, Test Acc: 0.5295, Elapsed Time: 1376.50s
# Step 1114/1490, Budget: 24508, Loss: 0.7555, Sup Loss: 0.1179, Unsup Loss: 0.6376, Test F1: 0.5353, Test Acc: 0.5437, Elapsed Time: 1417.34s
# Step 1146/1490, Budget: 25212, Loss: 0.7303, Sup Loss: 0.0815, Unsup Loss: 0.6487, Test F1: 0.5405, Test Acc: 0.5451, Elapsed Time: 1458.16s
# Step 1178/1490, Budget: 25916, Loss: 1.0093, Sup Loss: 0.1393, Unsup Loss: 0.8700, Test F1: 0.5445, Test Acc: 0.5520, Elapsed Time: 1497.86s
# Step 1210/1490, Budget: 26620, Loss: 0.7738, Sup Loss: 0.0988, Unsup Loss: 0.6750, Test F1: 0.5417, Test Acc: 0.5479, Elapsed Time: 1538.73s
# Step 1241/1490, Budget: 27302, Loss: 0.7713, Sup Loss: 0.0605, Unsup Loss: 0.7108, Test F1: 0.5448, Test Acc: 0.5523, Elapsed Time: 1578.29s
# Step 1273/1490, Budget: 28006, Loss: 0.6847, Sup Loss: 0.0843, Unsup Loss: 0.6005, Test F1: 0.5384, Test Acc: 0.5470, Elapsed Time: 1619.19s
# Step 1305/1490, Budget: 28710, Loss: 0.6662, Sup Loss: 0.0735, Unsup Loss: 0.5927, Test F1: 0.5400, Test Acc: 0.5480, Elapsed Time: 1659.98s
# Step 1337/1490, Budget: 29414, Loss: 0.6887, Sup Loss: 0.0438, Unsup Loss: 0.6449, Test F1: 0.5439, Test Acc: 0.5513, Elapsed Time: 1700.81s
# Step 1369/1490, Budget: 30118, Loss: 0.8251, Sup Loss: 0.0846, Unsup Loss: 0.7405, Test F1: 0.5416, Test Acc: 0.5504, Elapsed Time: 1741.72s
# Step 1400/1490, Budget: 30800, Loss: 0.8990, Sup Loss: 0.0679, Unsup Loss: 0.8312, Test F1: 0.5451, Test Acc: 0.5529, Elapsed Time: 1780.20s
# Step 1432/1490, Budget: 31504, Loss: 0.6419, Sup Loss: 0.0606, Unsup Loss: 0.5813, Test F1: 0.5447, Test Acc: 0.5516, Elapsed Time: 1821.12s
# Step 1464/1490, Budget: 32208, Loss: 0.7925, Sup Loss: 0.0564, Unsup Loss: 0.7361, Test F1: 0.5434, Test Acc: 0.5505, Elapsed Time: 1861.93s
# Step 1490/1490, Budget: 32780, Loss: 0.6640, Sup Loss: 0.0406, Unsup Loss: 0.6234, Test F1: 0.5457, Test Acc: 0.5525, Elapsed Time: 1895.36s
