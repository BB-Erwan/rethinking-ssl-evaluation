# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, Subset, Dataset
import sys 
sys.path.append("../")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
num_classes = 10

# Load the CIFAR-10 dataset
train_ds = torchvision.datasets.CIFAR10(root='./data', train=True, download=True)
test_ds = torchvision.datasets.CIFAR10(root='./data', train=False, download=True)

print(f"Training samples: {len(train_ds)}, Test samples: {len(test_ds)}")

mean = torch.tensor([0.4914, 0.4822, 0.4465])
std = torch.tensor([0.2023, 0.1994, 0.2010])
# Out:
# Training samples: 50000, Test samples: 10000

# %%
class RandomRangAugment(transforms.RandAugment):
    def __init__(self, num_ops=2):
        super().__init__(num_ops=num_ops)

    def __call__(self, img):
        # just randaugment with random magnitude
        self.magnitude = torch.randint(0, self.num_magnitude_bins, (1,)).item()
        img = super().__call__(img)
        return img

# %%
norm_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize(mean, std)
    ])

weak_transform = transforms.Compose([
        transforms.RandomHorizontalFlip(),
        transforms.RandomCrop(32, padding=4),
        transforms.ToTensor(),
        transforms.Normalize(mean, std)
    ])

medium_transform = transforms.Compose([
        transforms.RandomHorizontalFlip(),
        transforms.RandomCrop(32, padding=4),
        RandomRangAugment(num_ops=1),
        transforms.ToTensor(),
        transforms.Normalize(mean, std),
        transforms.RandomErasing(),
    ])

strong_transform=transforms.Compose([
        RandomRangAugment(num_ops=3),
        transforms.ToTensor(),
        transforms.Normalize(mean, std),
        transforms.RandomErasing()
    ])

# %%
# Test transformation on a sample image
import matplotlib.pyplot as plt
def imshow(img, title=None):
    img = img * std[:, None, None] + mean[:, None, None]  # unnormalize
    img = img.permute(1, 2, 0).numpy()  # CxHxW to HxWxC
    plt.imshow(img)
    if title:
        plt.title(title)
    plt.axis('off')
sample_img, sample_label = train_ds[0]
plt.figure(figsize=(12, 4))
plt.subplot(1, 4, 1)
imshow(norm_transform(sample_img), title="Original")
plt.subplot(1, 4, 2)
imshow(weak_transform(sample_img), title="Weak")
plt.subplot(1, 4, 3)
imshow(medium_transform(sample_img), title="Medium")
plt.subplot(1, 4, 4)
imshow(strong_transform(sample_img), title="Strong")
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.9802322e-08..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.9802322e-08..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.9802322e-08..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.9802322e-08..0.972549].

# %%
class UnlabeledDataset(Dataset):
    def __init__(self, dataset, weak_transform, medium_transform, strong_transform):
        self.dataset = dataset
        self.weak_transform = weak_transform
        self.medium_transform = medium_transform
        self.strong_transform = strong_transform

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        x, _ = self.dataset[idx]
        x_w = self.weak_transform(x)
        x_m = self.medium_transform(x)
        x_s = self.strong_transform(x)
        return x_w, x_m, x_s, idx

# %%
from datasets import TransformedDataset
from wideresnet2 import WideResNet 
from utils import evaluate_f1_and_accuracy
import os
import json
import time

num_runs = 3

test_ds = TransformedDataset(test_ds, norm_transform)

for run in range(num_runs):
    print(f"Run {run+1}/{num_runs}")

    # Init random seeds for reproducibility
    torch.manual_seed(run)
    num_labeled = 40
    perm_indices = torch.randperm(len(train_ds))
    labeled_indices = perm_indices[:num_labeled]
    unlabeled_indices = perm_indices[num_labeled:]

    # Create datasets and dataloaders
    labeled_ds = TransformedDataset(Subset(train_ds, labeled_indices), weak_transform)
    unlabeled_ds = UnlabeledDataset(Subset(train_ds, unlabeled_indices), weak_transform, medium_transform, strong_transform)

    # Create dataloaders
    batch_size = 64
    mu = 7
    labeled_loader = DataLoader(labeled_ds, batch_size=batch_size, shuffle=True)
    unlabeled_loader = DataLoader(unlabeled_ds, batch_size=batch_size*mu, shuffle=True)
    test_loader = DataLoader(test_ds, batch_size=batch_size, shuffle=False)

    # Create iterators for the dataloaders
    labeled_iter = iter(labeled_loader)
    unlabeled_iter = iter(unlabeled_loader)

    # Define the model
    model = WideResNet(depth=28, widen_factor=2, num_classes=num_classes).to(device)
    max_steps = 3_550  # Equivalent to 100 epochs on the full dataset with batch size 64
    optimizer = torch.optim.SGD(model.parameters(), lr=0.03, momentum=0.9, weight_decay=5e-4, nesterov=True)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=max_steps)

    # Settings
    method_name = "SequenceMatch"
    name_of_experiment = f"cifar10_{num_labeled}_labels_run_{run+1}"

    if os.path.exists(f"results/{name_of_experiment}/{method_name}.json"):
        print(f"Results for {name_of_experiment} already exist. Skipping saving to avoid overwriting.")
        break # this will skip the rest of the training loop and move to the next run

    # Metrics to track
    metrics = {
    "test_f1": [0.0],  # Start with 0% F1 before training
    "test_acc": [0.0],  # Start with 0% accuracy before training
    "budget": [0]
    }

    # Hyperparameters
    tau = 0.95
    T = 0.5
    budget_per_iteration = 1 + 3 * mu  # 1 batch of labeled + 3 batches of unlabeled (weak + medium + strong)
    test_budget_period = 1500  # Evaluate on test set every 1500 batches seen

    # Training loop
    current_budget = 0
    start_time = time.time()
    for step in range(max_steps):
        running_loss = 0.0
        running_loss_sup = 0.0
        running_loss_unsup = 0.0
        model.train()
        try:
            x_l, y_l = next(labeled_iter)
        except StopIteration:
            labeled_iter = iter(labeled_loader)
            x_l, y_l = next(labeled_iter)

        try:
            x_u_w, x_u_m, x_u_s, _ = next(unlabeled_iter)
        except StopIteration:
            unlabeled_iter = iter(unlabeled_loader)
            x_u_w, x_u_m, x_u_s, _ = next(unlabeled_iter)

        x_l, y_l = x_l.to(device), y_l.to(device)
        x_u_w, x_u_m, x_u_s = x_u_w.to(device), x_u_m.to(device), x_u_s.to(device)

        # supervised
        logits_l = model(x_l)
        loss_sup = F.cross_entropy(logits_l, y_l)

        # compute prediction on weakly augmented samples for pseudo-labeling and confidence-based masking
        logits_m = model(x_u_m)
        logits_s = model(x_u_s)
        with torch.no_grad():
            logits_w = model(x_u_w)
            probs_w = F.softmax(logits_w, dim=1)
            sharpened_probs_w = F.softmax(logits_w / T, dim=1)
            max_prob_w, pseudo_w = torch.max(probs_w, dim=1)
            mask_w = max_prob_w.ge(tau).float()

            probs_m = F.softmax(logits_m, dim=1)
            sharpened_probs_m = F.softmax(logits_m / T, dim=1)
            max_prob_m, pseudo_m = torch.max(probs_m, dim=1)
            mask_m = max_prob_m.ge(tau).float()

        loss_unsup_conf = (mask_w * F.cross_entropy(logits_s, pseudo_w, reduction='none')).mean()

        loss_consistency = loss_unsup_conf

        loss_w_m = (mask_w * F.kl_div(F.log_softmax(logits_m, dim=1), sharpened_probs_w, reduction='none').sum(dim=1)).mean()
        loss_m_s = (mask_m * F.kl_div(F.log_softmax(logits_s, dim=1), sharpened_probs_m, reduction='none').sum(dim=1)).mean()
        loss_w_s = (mask_w * F.kl_div(F.log_softmax(logits_s, dim=1), sharpened_probs_w, reduction='none').sum(dim=1)).mean()

        loss_unsup = loss_w_m + loss_m_s + loss_w_s  + loss_consistency 

        loss = loss_sup + loss_unsup
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        scheduler.step()

        running_loss += loss.item()
        running_loss_sup += loss_sup.item()
        running_loss_unsup += loss_unsup.item()

        current_budget += budget_per_iteration

        if current_budget % test_budget_period < budget_per_iteration:
            f1, acc = evaluate_f1_and_accuracy(model, test_loader, device)
            metrics["test_f1"].append(f1)
            metrics["test_acc"].append(acc)
            metrics["budget"].append(current_budget)
            elapsed_time = time.time() - start_time
            print(f"Step {step+1}/{max_steps}, Budget: {current_budget}, Loss: {running_loss:.4f}, Sup Loss: {running_loss_sup:.4f}, Unsup Loss: {running_loss_unsup:.4f}, Test F1: {f1:.4f}, Test Acc: {acc:.4f}, Elapsed Time: {elapsed_time:.2f}s", flush=True)

            os.makedirs("results", exist_ok=True)
            os.makedirs(f"results/{name_of_experiment}", exist_ok=True)
            with open(f"results/{name_of_experiment}/{method_name}.json", "w") as f:
                json.dump(metrics, f, indent=4)

            # Early stopping if divergence is detected (accuracy does not go above 11% for 5 consecutive evaluations)
            early_stopping = (num_labeled == 40) and len(metrics["test_acc"]) > 5 and all(acc <= 0.11 for acc in metrics["test_acc"][-6:-1])
            if early_stopping:
                print(f"Early stopping at step {step+1} due to accuracy stagnating.")
                
                # Fill the remaining metrics with the last known values until max_steps
                for remaining_step in range(step+1, max_steps):
                    current_budget += budget_per_iteration
                    if current_budget % test_budget_period < budget_per_iteration:
                        metrics["test_f1"].append(metrics["test_f1"][-1])  # Append last known F1
                        metrics["test_acc"].append(metrics["test_acc"][-1])  # Append last known accuracy
                        metrics["budget"].append(current_budget)
                # Save the final metrics after early stopping
                with open(f"results/{name_of_experiment}/{method_name}.json", "w") as f:
                    json.dump(metrics, f, indent=4)
                break  

        elif step+1 == max_steps: # Final evaluation at the end of training
            f1, acc = evaluate_f1_and_accuracy(model, test_loader, device)
            metrics["test_f1"].append(f1)
            metrics["test_acc"].append(acc)
            metrics["budget"].append(current_budget)
            elapsed_time = time.time() - start_time
            print(f"Step {step+1}/{max_steps}, Budget: {current_budget}, Loss: {running_loss:.4f}, Sup Loss: {running_loss_sup:.4f}, Unsup Loss: {running_loss_unsup:.4f}, Test F1: {f1:.4f}, Test Acc: {acc:.4f}, Elapsed Time: {elapsed_time:.2f}s", flush=True)

            os.makedirs("results", exist_ok=True)
            os.makedirs(f"results/{name_of_experiment}", exist_ok=True)
            with open(f"results/{name_of_experiment}/{method_name}.json", "w") as f:
                json.dump(metrics, f, indent=4) 

        else:
            print(f"Step {step+1}/{max_steps}, Budget: {current_budget}, Loss: {running_loss:.4f}, Sup Loss: {running_loss_sup:.4f}, Unsup Loss: {running_loss_unsup:.4f}", end="\r", flush=True)
# Out:
# Run 1/3
# Step 69/3550, Budget: 1518, Loss: 0.7608, Sup Loss: 0.3404, Unsup Loss: 0.4203, Test F1: 0.1428, Test Acc: 0.1812, Elapsed Time: 41.39s
# Step 137/3550, Budget: 3014, Loss: 0.7524, Sup Loss: 0.0490, Unsup Loss: 0.7033, Test F1: 0.1459, Test Acc: 0.1981, Elapsed Time: 80.75s
# Step 205/3550, Budget: 4510, Loss: 0.5664, Sup Loss: 0.0479, Unsup Loss: 0.5185, Test F1: 0.1812, Test Acc: 0.2092, Elapsed Time: 120.74s
# Step 273/3550, Budget: 6006, Loss: 0.7435, Sup Loss: 0.0354, Unsup Loss: 0.7080, Test F1: 0.1957, Test Acc: 0.2181, Elapsed Time: 158.96s
# Step 341/3550, Budget: 7502, Loss: 0.4757, Sup Loss: 0.0403, Unsup Loss: 0.4354, Test F1: 0.1685, Test Acc: 0.1996, Elapsed Time: 196.16s
# Step 410/3550, Budget: 9020, Loss: 1.0510, Sup Loss: 0.0393, Unsup Loss: 1.0117, Test F1: 0.1938, Test Acc: 0.2038, Elapsed Time: 234.20s
# Step 478/3550, Budget: 10516, Loss: 1.2109, Sup Loss: 0.0186, Unsup Loss: 1.1923, Test F1: 0.2040, Test Acc: 0.2273, Elapsed Time: 272.09s
# Step 546/3550, Budget: 12012, Loss: 1.2415, Sup Loss: 0.0121, Unsup Loss: 1.2294, Test F1: 0.2289, Test Acc: 0.2339, Elapsed Time: 309.87s
# Step 614/3550, Budget: 13508, Loss: 0.8764, Sup Loss: 0.0099, Unsup Loss: 0.8664, Test F1: 0.2277, Test Acc: 0.2511, Elapsed Time: 347.34s
# Step 682/3550, Budget: 15004, Loss: 1.0300, Sup Loss: 0.0112, Unsup Loss: 1.0188, Test F1: 0.2073, Test Acc: 0.2117, Elapsed Time: 384.20s
# Step 750/3550, Budget: 16500, Loss: 1.0046, Sup Loss: 0.0139, Unsup Loss: 0.9908, Test F1: 0.2539, Test Acc: 0.2545, Elapsed Time: 421.99s
# Step 819/3550, Budget: 18018, Loss: 1.2107, Sup Loss: 0.0089, Unsup Loss: 1.2019, Test F1: 0.2376, Test Acc: 0.2433, Elapsed Time: 459.56s
# Step 887/3550, Budget: 19514, Loss: 1.0925, Sup Loss: 0.0067, Unsup Loss: 1.0859, Test F1: 0.2581, Test Acc: 0.2607, Elapsed Time: 497.52s
# Step 955/3550, Budget: 21010, Loss: 1.3253, Sup Loss: 0.0143, Unsup Loss: 1.3110, Test F1: 0.2796, Test Acc: 0.2868, Elapsed Time: 535.10s
# Step 1023/3550, Budget: 22506, Loss: 1.0845, Sup Loss: 0.0061, Unsup Loss: 1.0785, Test F1: 0.2733, Test Acc: 0.2891, Elapsed Time: 572.33s
# Step 1091/3550, Budget: 24002, Loss: 1.0492, Sup Loss: 0.0097, Unsup Loss: 1.0395, Test F1: 0.2996, Test Acc: 0.3053, Elapsed Time: 611.00s
# Step 1160/3550, Budget: 25520, Loss: 1.3544, Sup Loss: 0.0056, Unsup Loss: 1.3487, Test F1: 0.2876, Test Acc: 0.2916, Elapsed Time: 649.09s
# Step 1228/3550, Budget: 27016, Loss: 1.0777, Sup Loss: 0.0051, Unsup Loss: 1.0726, Test F1: 0.2587, Test Acc: 0.2569, Elapsed Time: 687.33s
# Step 1296/3550, Budget: 28512, Loss: 1.0259, Sup Loss: 0.0061, Unsup Loss: 1.0198, Test F1: 0.2944, Test Acc: 0.3044, Elapsed Time: 724.71s
# Step 1364/3550, Budget: 30008, Loss: 1.1678, Sup Loss: 0.0075, Unsup Loss: 1.1603, Test F1: 0.2722, Test Acc: 0.2746, Elapsed Time: 762.07s
# Step 1432/3550, Budget: 31504, Loss: 0.9667, Sup Loss: 0.0046, Unsup Loss: 0.9622, Test F1: 0.2780, Test Acc: 0.2900, Elapsed Time: 800.44s
# Step 1500/3550, Budget: 33000, Loss: 1.1272, Sup Loss: 0.0036, Unsup Loss: 1.1236, Test F1: 0.3092, Test Acc: 0.3213, Elapsed Time: 838.65s
# Step 1569/3550, Budget: 34518, Loss: 0.9644, Sup Loss: 0.0035, Unsup Loss: 0.9609, Test F1: 0.2947, Test Acc: 0.3110, Elapsed Time: 876.95s
# Step 1637/3550, Budget: 36014, Loss: 1.0788, Sup Loss: 0.0041, Unsup Loss: 1.0747, Test F1: 0.2759, Test Acc: 0.2862, Elapsed Time: 915.61s
# Step 1705/3550, Budget: 37510, Loss: 1.0007, Sup Loss: 0.0050, Unsup Loss: 0.9957, Test F1: 0.2825, Test Acc: 0.2886, Elapsed Time: 954.29s
# Step 1773/3550, Budget: 39006, Loss: 0.9252, Sup Loss: 0.0045, Unsup Loss: 0.9207, Test F1: 0.2877, Test Acc: 0.3049, Elapsed Time: 993.27s
# Step 1841/3550, Budget: 40502, Loss: 0.9963, Sup Loss: 0.0023, Unsup Loss: 0.9940, Test F1: 0.2772, Test Acc: 0.2860, Elapsed Time: 1032.40s
# Step 1910/3550, Budget: 42020, Loss: 0.9913, Sup Loss: 0.0078, Unsup Loss: 0.9835, Test F1: 0.2782, Test Acc: 0.2884, Elapsed Time: 1072.45s
# Step 1978/3550, Budget: 43516, Loss: 0.9549, Sup Loss: 0.0032, Unsup Loss: 0.9517, Test F1: 0.2973, Test Acc: 0.3096, Elapsed Time: 1110.78s
# Step 2046/3550, Budget: 45012, Loss: 1.0656, Sup Loss: 0.0040, Unsup Loss: 1.0615, Test F1: 0.2929, Test Acc: 0.3047, Elapsed Time: 1148.54s
# Step 2114/3550, Budget: 46508, Loss: 1.0345, Sup Loss: 0.0038, Unsup Loss: 1.0307, Test F1: 0.3118, Test Acc: 0.3282, Elapsed Time: 1187.58s
# Step 2182/3550, Budget: 48004, Loss: 1.0019, Sup Loss: 0.0038, Unsup Loss: 0.9981, Test F1: 0.2863, Test Acc: 0.2969, Elapsed Time: 1226.33s
# Step 2250/3550, Budget: 49500, Loss: 0.8166, Sup Loss: 0.0034, Unsup Loss: 0.8132, Test F1: 0.2963, Test Acc: 0.3054, Elapsed Time: 1265.51s
# Step 2319/3550, Budget: 51018, Loss: 0.8081, Sup Loss: 0.0035, Unsup Loss: 0.8046, Test F1: 0.2841, Test Acc: 0.3018, Elapsed Time: 1305.58s
# Step 2387/3550, Budget: 52514, Loss: 0.9362, Sup Loss: 0.0024, Unsup Loss: 0.9338, Test F1: 0.3106, Test Acc: 0.3180, Elapsed Time: 1344.90s
# Step 2455/3550, Budget: 54010, Loss: 0.8593, Sup Loss: 0.0040, Unsup Loss: 0.8553, Test F1: 0.3141, Test Acc: 0.3285, Elapsed Time: 1383.87s
# Step 2523/3550, Budget: 55506, Loss: 0.7448, Sup Loss: 0.0022, Unsup Loss: 0.7426, Test F1: 0.2935, Test Acc: 0.3076, Elapsed Time: 1422.40s
# Step 2591/3550, Budget: 57002, Loss: 0.9327, Sup Loss: 0.0021, Unsup Loss: 0.9306, Test F1: 0.2959, Test Acc: 0.3099, Elapsed Time: 1461.07s
# Step 2660/3550, Budget: 58520, Loss: 0.9307, Sup Loss: 0.0017, Unsup Loss: 0.9290, Test F1: 0.3183, Test Acc: 0.3287, Elapsed Time: 1500.45s
# Step 2728/3550, Budget: 60016, Loss: 0.7451, Sup Loss: 0.0022, Unsup Loss: 0.7430, Test F1: 0.2915, Test Acc: 0.3081, Elapsed Time: 1538.92s
# Step 2796/3550, Budget: 61512, Loss: 0.7975, Sup Loss: 0.0020, Unsup Loss: 0.7956, Test F1: 0.2844, Test Acc: 0.3014, Elapsed Time: 1577.68s
# Step 2864/3550, Budget: 63008, Loss: 0.7854, Sup Loss: 0.0019, Unsup Loss: 0.7835, Test F1: 0.2937, Test Acc: 0.3106, Elapsed Time: 1616.14s
# Step 2932/3550, Budget: 64504, Loss: 1.0850, Sup Loss: 0.0016, Unsup Loss: 1.0834, Test F1: 0.3013, Test Acc: 0.3184, Elapsed Time: 1654.66s
# Step 3000/3550, Budget: 66000, Loss: 0.8827, Sup Loss: 0.0014, Unsup Loss: 0.8813, Test F1: 0.3000, Test Acc: 0.3173, Elapsed Time: 1693.27s
# Step 3069/3550, Budget: 67518, Loss: 0.8909, Sup Loss: 0.0016, Unsup Loss: 0.8893, Test F1: 0.2979, Test Acc: 0.3121, Elapsed Time: 1732.71s
# Step 3137/3550, Budget: 69014, Loss: 0.7401, Sup Loss: 0.0019, Unsup Loss: 0.7382, Test F1: 0.2963, Test Acc: 0.3134, Elapsed Time: 1770.97s
# Step 3205/3550, Budget: 70510, Loss: 0.7090, Sup Loss: 0.0016, Unsup Loss: 0.7074, Test F1: 0.2955, Test Acc: 0.3124, Elapsed Time: 1810.06s
# Step 3273/3550, Budget: 72006, Loss: 0.8733, Sup Loss: 0.0015, Unsup Loss: 0.8718, Test F1: 0.2973, Test Acc: 0.3119, Elapsed Time: 1849.83s
# Step 3341/3550, Budget: 73502, Loss: 0.7989, Sup Loss: 0.0015, Unsup Loss: 0.7974, Test F1: 0.2945, Test Acc: 0.3104, Elapsed Time: 1889.46s
# Step 3410/3550, Budget: 75020, Loss: 0.7944, Sup Loss: 0.0014, Unsup Loss: 0.7930, Test F1: 0.2952, Test Acc: 0.3104, Elapsed Time: 1928.32s
# Step 3478/3550, Budget: 76516, Loss: 0.8379, Sup Loss: 0.0012, Unsup Loss: 0.8368, Test F1: 0.2967, Test Acc: 0.3115, Elapsed Time: 1966.87s
# Step 3546/3550, Budget: 78012, Loss: 0.8232, Sup Loss: 0.0012, Unsup Loss: 0.8219, Test F1: 0.2959, Test Acc: 0.3109, Elapsed Time: 2005.53s
# Step 3550/3550, Budget: 78100, Loss: 0.8659, Sup Loss: 0.0016, Unsup Loss: 0.8643, Test F1: 0.2954, Test Acc: 0.3118, Elapsed Time: 2009.00s
# Run 2/3
# Step 69/3550, Budget: 1518, Loss: 0.8492, Sup Loss: 0.2523, Unsup Loss: 0.5969, Test F1: 0.1396, Test Acc: 0.1657, Elapsed Time: 38.70s
# Step 137/3550, Budget: 3014, Loss: 0.6990, Sup Loss: 0.0365, Unsup Loss: 0.6625, Test F1: 0.1309, Test Acc: 0.1725, Elapsed Time: 75.65s
# Step 205/3550, Budget: 4510, Loss: 0.3804, Sup Loss: 0.0306, Unsup Loss: 0.3499, Test F1: 0.1050, Test Acc: 0.1786, Elapsed Time: 112.95s
# Step 273/3550, Budget: 6006, Loss: 0.6572, Sup Loss: 0.0175, Unsup Loss: 0.6397, Test F1: 0.1112, Test Acc: 0.1750, Elapsed Time: 149.99s
# Step 341/3550, Budget: 7502, Loss: 0.6455, Sup Loss: 0.0061, Unsup Loss: 0.6395, Test F1: 0.1178, Test Acc: 0.1781, Elapsed Time: 186.87s
# Step 410/3550, Budget: 9020, Loss: 0.4415, Sup Loss: 0.0141, Unsup Loss: 0.4274, Test F1: 0.1018, Test Acc: 0.1764, Elapsed Time: 224.51s
# Step 478/3550, Budget: 10516, Loss: 0.0252, Sup Loss: 0.0117, Unsup Loss: 0.0135, Test F1: 0.0295, Test Acc: 0.1062, Elapsed Time: 261.74s
# Step 546/3550, Budget: 12012, Loss: 0.0069, Sup Loss: 0.0032, Unsup Loss: 0.0037, Test F1: 0.0184, Test Acc: 0.1001, Elapsed Time: 300.02s
# Step 614/3550, Budget: 13508, Loss: 0.0044, Sup Loss: 0.0020, Unsup Loss: 0.0024, Test F1: 0.0182, Test Acc: 0.1000, Elapsed Time: 337.10s
# Step 682/3550, Budget: 15004, Loss: 0.0038, Sup Loss: 0.0018, Unsup Loss: 0.0020, Test F1: 0.0182, Test Acc: 0.1000, Elapsed Time: 374.19s
# Step 750/3550, Budget: 16500, Loss: 0.0032, Sup Loss: 0.0014, Unsup Loss: 0.0017, Test F1: 0.0182, Test Acc: 0.1000, Elapsed Time: 411.35s
# Step 819/3550, Budget: 18018, Loss: 0.0032, Sup Loss: 0.0013, Unsup Loss: 0.0019, Test F1: 0.0182, Test Acc: 0.1000, Elapsed Time: 448.92s
# Early stopping at step 819 due to accuracy stagnating.
# Run 3/3
# Step 69/3550, Budget: 1518, Loss: 0.6562, Sup Loss: 0.2450, Unsup Loss: 0.4112, Test F1: 0.1809, Test Acc: 0.2052, Elapsed Time: 37.72s
# Step 137/3550, Budget: 3014, Loss: 0.6157, Sup Loss: 0.0364, Unsup Loss: 0.5793, Test F1: 0.2023, Test Acc: 0.2294, Elapsed Time: 74.98s
# Step 205/3550, Budget: 4510, Loss: 0.3443, Sup Loss: 0.0329, Unsup Loss: 0.3114, Test F1: 0.1444, Test Acc: 0.1921, Elapsed Time: 112.05s
# Step 273/3550, Budget: 6006, Loss: 0.9508, Sup Loss: 0.0572, Unsup Loss: 0.8936, Test F1: 0.1935, Test Acc: 0.2286, Elapsed Time: 149.26s
# Step 341/3550, Budget: 7502, Loss: 0.4239, Sup Loss: 0.0131, Unsup Loss: 0.4108, Test F1: 0.1240, Test Acc: 0.1948, Elapsed Time: 186.36s
# Step 410/3550, Budget: 9020, Loss: 0.7261, Sup Loss: 0.0484, Unsup Loss: 0.6777, Test F1: 0.1692, Test Acc: 0.2204, Elapsed Time: 224.10s
# Step 478/3550, Budget: 10516, Loss: 0.5775, Sup Loss: 0.0168, Unsup Loss: 0.5607, Test F1: 0.0970, Test Acc: 0.1968, Elapsed Time: 261.08s
# Step 546/3550, Budget: 12012, Loss: 0.4504, Sup Loss: 0.0085, Unsup Loss: 0.4419, Test F1: 0.1024, Test Acc: 0.2056, Elapsed Time: 298.14s
# Step 614/3550, Budget: 13508, Loss: 0.5503, Sup Loss: 0.0373, Unsup Loss: 0.5131, Test F1: 0.1610, Test Acc: 0.2017, Elapsed Time: 335.12s
# Step 682/3550, Budget: 15004, Loss: 0.5584, Sup Loss: 0.0065, Unsup Loss: 0.5520, Test F1: 0.0938, Test Acc: 0.1999, Elapsed Time: 372.11s
# Step 750/3550, Budget: 16500, Loss: 0.5902, Sup Loss: 0.0044, Unsup Loss: 0.5858, Test F1: 0.0923, Test Acc: 0.2022, Elapsed Time: 409.43s
# Step 819/3550, Budget: 18018, Loss: 0.6137, Sup Loss: 0.0051, Unsup Loss: 0.6086, Test F1: 0.0911, Test Acc: 0.1991, Elapsed Time: 446.87s
# Step 887/3550, Budget: 19514, Loss: 0.3318, Sup Loss: 0.0032, Unsup Loss: 0.3286, Test F1: 0.0949, Test Acc: 0.2086, Elapsed Time: 483.98s
# Step 955/3550, Budget: 21010, Loss: 0.4449, Sup Loss: 0.0070, Unsup Loss: 0.4379, Test F1: 0.0964, Test Acc: 0.2059, Elapsed Time: 520.99s
# Step 1023/3550, Budget: 22506, Loss: 0.3527, Sup Loss: 0.0034, Unsup Loss: 0.3493, Test F1: 0.0909, Test Acc: 0.1998, Elapsed Time: 558.96s
# Step 1091/3550, Budget: 24002, Loss: 0.4539, Sup Loss: 0.0028, Unsup Loss: 0.4511, Test F1: 0.0950, Test Acc: 0.2089, Elapsed Time: 596.91s
# Step 1160/3550, Budget: 25520, Loss: 0.3786, Sup Loss: 0.0026, Unsup Loss: 0.3759, Test F1: 0.0934, Test Acc: 0.2045, Elapsed Time: 634.68s
# Step 1228/3550, Budget: 27016, Loss: 0.4827, Sup Loss: 0.0016, Unsup Loss: 0.4811, Test F1: 0.0932, Test Acc: 0.2045, Elapsed Time: 672.42s
# Step 1296/3550, Budget: 28512, Loss: 0.4695, Sup Loss: 0.0052, Unsup Loss: 0.4643, Test F1: 0.0925, Test Acc: 0.2040, Elapsed Time: 710.01s
# Step 1364/3550, Budget: 30008, Loss: 0.3855, Sup Loss: 0.0028, Unsup Loss: 0.3827, Test F1: 0.0936, Test Acc: 0.2062, Elapsed Time: 747.93s
# Step 1432/3550, Budget: 31504, Loss: 0.4069, Sup Loss: 0.0017, Unsup Loss: 0.4052, Test F1: 0.0959, Test Acc: 0.2082, Elapsed Time: 786.89s
# Step 1500/3550, Budget: 33000, Loss: 0.4444, Sup Loss: 0.0023, Unsup Loss: 0.4421, Test F1: 0.0929, Test Acc: 0.2059, Elapsed Time: 825.84s
# Step 1569/3550, Budget: 34518, Loss: 0.4177, Sup Loss: 0.0029, Unsup Loss: 0.4148, Test F1: 0.0931, Test Acc: 0.2052, Elapsed Time: 865.09s
# Step 1637/3550, Budget: 36014, Loss: 0.4573, Sup Loss: 0.0032, Unsup Loss: 0.4541, Test F1: 0.0929, Test Acc: 0.2064, Elapsed Time: 903.81s
# Step 1705/3550, Budget: 37510, Loss: 0.3975, Sup Loss: 0.0021, Unsup Loss: 0.3954, Test F1: 0.0949, Test Acc: 0.2087, Elapsed Time: 942.54s
# Step 1773/3550, Budget: 39006, Loss: 0.4706, Sup Loss: 0.0014, Unsup Loss: 0.4692, Test F1: 0.0944, Test Acc: 0.2080, Elapsed Time: 981.39s
# Step 1841/3550, Budget: 40502, Loss: 0.4318, Sup Loss: 0.0011, Unsup Loss: 0.4307, Test F1: 0.0940, Test Acc: 0.2082, Elapsed Time: 1020.71s
# Step 1910/3550, Budget: 42020, Loss: 0.4845, Sup Loss: 0.0013, Unsup Loss: 0.4832, Test F1: 0.0977, Test Acc: 0.2144, Elapsed Time: 1060.49s
# Step 1978/3550, Budget: 43516, Loss: 0.4092, Sup Loss: 0.0012, Unsup Loss: 0.4080, Test F1: 0.0963, Test Acc: 0.2118, Elapsed Time: 1100.34s
# Step 2046/3550, Budget: 45012, Loss: 0.5236, Sup Loss: 0.0025, Unsup Loss: 0.5211, Test F1: 0.0956, Test Acc: 0.2115, Elapsed Time: 1138.38s
# Step 2114/3550, Budget: 46508, Loss: 0.3479, Sup Loss: 0.0019, Unsup Loss: 0.3460, Test F1: 0.0982, Test Acc: 0.2153, Elapsed Time: 1175.61s
# Step 2182/3550, Budget: 48004, Loss: 0.4273, Sup Loss: 0.0009, Unsup Loss: 0.4265, Test F1: 0.0970, Test Acc: 0.2143, Elapsed Time: 1212.28s
# Step 2250/3550, Budget: 49500, Loss: 0.5248, Sup Loss: 0.0010, Unsup Loss: 0.5237, Test F1: 0.0958, Test Acc: 0.2107, Elapsed Time: 1251.22s
# Step 2319/3550, Budget: 51018, Loss: 0.4502, Sup Loss: 0.0025, Unsup Loss: 0.4477, Test F1: 0.0984, Test Acc: 0.2156, Elapsed Time: 1290.75s
# Step 2387/3550, Budget: 52514, Loss: 0.4227, Sup Loss: 0.0014, Unsup Loss: 0.4213, Test F1: 0.0983, Test Acc: 0.2157, Elapsed Time: 1329.43s
# Step 2455/3550, Budget: 54010, Loss: 0.3691, Sup Loss: 0.0016, Unsup Loss: 0.3674, Test F1: 0.0995, Test Acc: 0.2181, Elapsed Time: 1368.21s
# Step 2523/3550, Budget: 55506, Loss: 0.4329, Sup Loss: 0.0008, Unsup Loss: 0.4321, Test F1: 0.0986, Test Acc: 0.2168, Elapsed Time: 1405.55s
# Step 2591/3550, Budget: 57002, Loss: 0.3807, Sup Loss: 0.0010, Unsup Loss: 0.3798, Test F1: 0.0969, Test Acc: 0.2137, Elapsed Time: 1444.29s
# Step 2660/3550, Budget: 58520, Loss: 0.3890, Sup Loss: 0.0014, Unsup Loss: 0.3876, Test F1: 0.1008, Test Acc: 0.2202, Elapsed Time: 1483.85s
# Step 2728/3550, Budget: 60016, Loss: 0.3863, Sup Loss: 0.0017, Unsup Loss: 0.3846, Test F1: 0.1006, Test Acc: 0.2199, Elapsed Time: 1522.20s
# Step 2796/3550, Budget: 61512, Loss: 0.4266, Sup Loss: 0.0009, Unsup Loss: 0.4257, Test F1: 0.1012, Test Acc: 0.2211, Elapsed Time: 1560.67s
# Step 2864/3550, Budget: 63008, Loss: 0.4171, Sup Loss: 0.0007, Unsup Loss: 0.4164, Test F1: 0.0993, Test Acc: 0.2185, Elapsed Time: 1599.33s
# Step 2932/3550, Budget: 64504, Loss: 0.3651, Sup Loss: 0.0010, Unsup Loss: 0.3641, Test F1: 0.1009, Test Acc: 0.2212, Elapsed Time: 1637.99s
# Step 3000/3550, Budget: 66000, Loss: 0.4846, Sup Loss: 0.0010, Unsup Loss: 0.4836, Test F1: 0.0998, Test Acc: 0.2192, Elapsed Time: 1676.69s
# Step 3069/3550, Budget: 67518, Loss: 0.3717, Sup Loss: 0.0007, Unsup Loss: 0.3710, Test F1: 0.0988, Test Acc: 0.2174, Elapsed Time: 1715.94s
# Step 3137/3550, Budget: 69014, Loss: 0.3212, Sup Loss: 0.0010, Unsup Loss: 0.3203, Test F1: 0.0996, Test Acc: 0.2188, Elapsed Time: 1754.60s
# Step 3205/3550, Budget: 70510, Loss: 0.5396, Sup Loss: 0.0010, Unsup Loss: 0.5387, Test F1: 0.0990, Test Acc: 0.2175, Elapsed Time: 1794.85s
# Step 3273/3550, Budget: 72006, Loss: 0.4225, Sup Loss: 0.0011, Unsup Loss: 0.4214, Test F1: 0.0996, Test Acc: 0.2188, Elapsed Time: 1833.82s
# Step 3341/3550, Budget: 73502, Loss: 0.4015, Sup Loss: 0.0006, Unsup Loss: 0.4009, Test F1: 0.0996, Test Acc: 0.2189, Elapsed Time: 1873.69s
# Step 3410/3550, Budget: 75020, Loss: 0.4490, Sup Loss: 0.0010, Unsup Loss: 0.4480, Test F1: 0.0997, Test Acc: 0.2190, Elapsed Time: 1913.13s
# Step 3478/3550, Budget: 76516, Loss: 0.4160, Sup Loss: 0.0007, Unsup Loss: 0.4152, Test F1: 0.0999, Test Acc: 0.2193, Elapsed Time: 1951.50s
# Step 3546/3550, Budget: 78012, Loss: 0.3340, Sup Loss: 0.0007, Unsup Loss: 0.3333, Test F1: 0.1001, Test Acc: 0.2195, Elapsed Time: 1989.96s
# Step 3550/3550, Budget: 78100, Loss: 0.4766, Sup Loss: 0.0007, Unsup Loss: 0.4759, Test F1: 0.0997, Test Acc: 0.2189, Elapsed Time: 1993.11s
